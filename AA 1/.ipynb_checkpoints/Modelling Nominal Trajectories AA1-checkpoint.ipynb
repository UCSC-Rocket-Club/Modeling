# %%
from matplotlib.pyplot import *
% matplotlib inline
from numpy import *
from astropy.io import ascii
import AA1 as AA

# %%
avionics = 0.211
rocket = 4.49+0.449-0.211
dry_motor = 1.264 - 0.745
wet_motor = 1.264

print rocket + avionics
# Out:
# 4.939

# %%
thrust_profile = 'K535_thrust.txt'
rocket_mass = avionics+rocket  #kg
time_res = 0.001
motor_mass = dry_motor
propellant_mass = wet_motor - dry_motor
burn_time = 2.8 # sec
temp = 10.   # Density of air varies with temperature


print rocket_mass + motor_mass  + propellant_mass
print rocket_mass + motor_mass

drag_f = 1.2#factor for adjusting the drag force on the rocket, set this to 1 when there is real life data in the drag arrays
# Out:
# 6.203
# 5.458

# %%
time, velocity, acceleration, height, mass, ADAS, apogee, MECO_vel = AA.num_solver(thrust_profile, rocket_mass, motor_mass, propellant_mass, time_res, temp, burn_time, 1, drag_f)
# Out:
# NumRootCalcLin.py:29: RuntimeWarning: overflow encountered in exp
#   return exp(x*alpha*height_diff)-sqrt(1+alpha*v_0**2*x/g)
# NumRootCalcLin.py:33: RuntimeWarning: overflow encountered in exp
#   return alpha*height_diff*exp(x*alpha*height_diff)-(alpha*v_0**2)/(2*g*sqrt(1+alpha*v_0**2*x/g))
# C:\Anaconda\lib\site-packages\scipy\interpolate\interpolate.py:634: RuntimeWarning: invalid value encountered in less
#   below_bounds = x_new < self.x[0]
# C:\Anaconda\lib\site-packages\scipy\interpolate\interpolate.py:635: RuntimeWarning: invalid value encountered in greater
#   above_bounds = x_new > self.x[-1]
# MECO at 2.8 sec, at 335.24 m
# Apogee at 14.78 sec, at 1604.52 m
# MECO at 204.33 m/s
