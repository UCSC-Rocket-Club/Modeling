# %%
from matplotlib.pyplot import *
% matplotlib inline
from numpy import *
from astropy.io import ascii
import DragScriptV83 as DS

# %%
avionics = 0.211
#rocket = 4.49+0.449-0.211####mass has been adjusted
rocket = 4.88-0.211
dry_motor = 1.264 - 0.745
wet_motor = 1.264

print rocket + avionics
# Out:
# 4.88

# %%
thrust_profile = 'K535_thrust.txt'
rocket_mass = avionics+rocket  #kg
time_res = 0.001
motor_mass = dry_motor
propellant_mass = wet_motor - dry_motor
burn_time = 2.8 # sec
temp = 10.   # Density of air varies with temperature


print rocket_mass + motor_mass  + propellant_mass
print rocket_mass + motor_mass

max_deploy = 74.9  #percentage opening


t_deploy = 1 #how long it takes to deploy
t_start = 0 # after MECO

drag_f = 1.19
# Out:
# 6.144
# 5.399

# %%
#time, velocity, acceleration, jerk, height, mass, ADAS, apogee, MECO_vel = DS.num_solver(thrust_profile, rocket_mass, motor_mass, propellant_mass, time_res, temp, burn_time, max_deploy, t_start, t_deploy, 1, drag_f)

# %%
k_h = 7
k_v = 14
k_a = 4
k_j = 0
scale = 30
ADAS_max_speed = 200

acc_noise = 0.1
vel_noise = 0.1
h_noise = 0



update_interval = time_res*100

# %%
time, velocity, acceleration, height, mass, ADAS, apogee, MECO_vel = DS.PID(thrust_profile, rocket_mass, motor_mass, propellant_mass, time_res, temp, burn_time, max_deploy, t_start, t_deploy, 1, drag_f, k_h, k_v, k_a, k_j, scale, ADAS_max_speed, update_interval, acc_noise, vel_noise, h_noise)
# Out:
# MECO at 2.8 sec, at 336.6 m
# Apogee at 17.72 sec, at 1609.72 m
# MECO at 203.39 m/s
