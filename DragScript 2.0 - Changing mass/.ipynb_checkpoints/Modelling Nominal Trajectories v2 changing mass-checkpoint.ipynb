# %%
from matplotlib.pyplot import *
% matplotlib inline
from numpy import *
from astropy.io import ascii
import DragScriptV2 as DS

# %%
avionics = 0.211
rocket = 4.58-0.211
dry_motor = 0.650 - 0.345
wet_motor = 0.650

print rocket + avionics
# Out:
# 4.58

# %%
thrust_profile = 'J420_thrust.txt'
rocket_mass = avionics+rocket  #kg
time_res = 0.005
motor_mass = dry_motor
propellant_mass = wet_motor - dry_motor
burn_time = 1.8 # sec
temp = 10.   # Density of air varies with temperature


print rocket_mass + motor_mass  + propellant_mass
print rocket_mass + motor_mass

#max_deploy = 60.6
max_deploy = 0


t_deploy = 1 #how long it takes to deploy
t_start = 0 # after MECO
# Out:
# 5.23
# 4.885

# %%
time, velocity, acceleration, height, mass, ADAS, apogee, MECO_vel = DS.num_solver(thrust_profile, rocket_mass, motor_mass, propellant_mass, time_res, temp, burn_time, max_deploy, t_start, t_deploy, 1)
# Out:
# MECO at 1.81 sec, at 124.1 m
# Apogee at 11.87 sec, at 643.55 m
# MECO at 108.45 m/s
