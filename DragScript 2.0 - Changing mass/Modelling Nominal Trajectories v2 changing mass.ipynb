# %%
from matplotlib.pyplot import *
% matplotlib inline
from numpy import *
from astropy.io import ascii
import DragScriptV2 as DS

# %%
avionics = 0.211
rocket = 4.58-0.211
dry_motor = 1.264 - 0.745
wet_motor = 1.264

print rocket + avionics
# Out:
# 4.58

# %%
thrust_profile = 'K535_thrust.txt'
rocket_mass = avionics+rocket  #kg
time_res = 0.005
motor_mass = dry_motor
propellant_mass = wet_motor - dry_motor
burn_time = 2.8 # sec
temp = 10.   # Density of air varies with temperature


print rocket_mass + motor_mass  + propellant_mass
print rocket_mass + motor_mass

#max_deploy = 60.6
max_deploy = 0


t_deploy = 1 #how long it takes to deploy
t_start = 0 # after MECO

mass_f = 0.721
# Out:
# 5.844
# 5.099

# %%
time, velocity, acceleration, height, mass, ADAS, apogee, MECO_vel = DS.num_solver(thrust_profile, rocket_mass, motor_mass, propellant_mass, time_res, temp, burn_time, max_deploy, t_start, t_deploy, 1, mass_f)
# Out:
# MECO at 2.81 sec, at 463.01 m
# Apogee at 20.62 sec, at 2366.49 m
# MECO at 278.13 m/s

# %%
avionics = 0.211
rocket = 4.58-0.649-0.211
dry_motor = 0.649 - 0.345
wet_motor = 0.649

print rocket + avionics
# Out:
# 3.931

# %%
thrust_profile = 'J420_thrust.txt'
rocket_mass = avionics+rocket  #kg
time_res = 0.005
motor_mass = dry_motor
propellant_mass = wet_motor - dry_motor
burn_time = 1.6 # sec
temp = 10.   # Density of air varies with temperature


print rocket_mass + motor_mass  + propellant_mass
print rocket_mass + motor_mass

#max_deploy = 60.6
max_deploy = 0

mass_f = 0.721

t_deploy = 1 #how long it takes to deploy
t_start = 0 # after MECO
# Out:
# 4.58
# 4.235

# %%
time, velocity, acceleration, height, mass, ADAS, apogee, MECO_vel = DS.num_solver(thrust_profile, rocket_mass, motor_mass, propellant_mass, time_res, temp, burn_time, max_deploy, t_start, t_deploy, 1, mass_f)
# Out:
# MECO at 1.61 sec, at 159.52 m
# Apogee at 14.73 sec, at 1122.72 m
# MECO at 172.04 m/s

# %%
avionics = 0.211
rocket = 4.67-0.211  #should be 4.58
dry_motor = 1.647 - 0.974
wet_motor = 1.647

print rocket + avionics
# Out:
# 4.67

# %%
thrust_profile = 'K513_thrust.txt'
rocket_mass = avionics+rocket  #kg
time_res = 0.005
motor_mass = dry_motor
propellant_mass = wet_motor - dry_motor
burn_time = 2.8 # sec
temp = 10.   # Density of air varies with temperature


print rocket_mass + motor_mass  + propellant_mass
print rocket_mass + motor_mass

#max_deploy = 60.6
max_deploy = 0


t_deploy = 1 #how long it takes to deploy
t_start = 0 # after MECO

mass_f = 0.721
# Out:
# 6.317
# 5.343

# %%
time, velocity, acceleration, height, mass, ADAS, apogee, MECO_vel = DS.num_solver(thrust_profile, rocket_mass, motor_mass, propellant_mass, time_res, temp, burn_time, max_deploy, t_start, t_deploy, 1, mass_f)
# Out:
# MECO at 2.81 sec, at 443.27 m
# Apogee at 20.52 sec, at 2297.58 m
# MECO at 267.79 m/s
